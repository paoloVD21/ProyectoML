# %% [markdown]
# # ABANCAY
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # ALTO AMAZONAS
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#
# # AMBO
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # ANDAHUAYLAS
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#   - CRAC (Tipo IFI)
#     - CRAC RAIZ (IFI)
#
# # ANTA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # AREQUIPA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
# - S-CRC (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # ASCOPE
# - FCTP (Producto)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # AYMARAES
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # AZANGARO
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # BARRANCA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
#
# # BELLAVISTA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # BOLOGNESI
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC TRUJILLO (IFI)
#
# # BONGARA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CAJAMARCA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#
# # CALCA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # CALLAO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - CRAC (Tipo IFI)
#     - CRAC RAIZ (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - S-CRC (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#
# # CAMANA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC ICA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CANCHIS
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC TRUJILLO (IFI)
#
# # CANDARAVE
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CANIETE
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#
# # CASMA
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # CAYLLOMA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
# # CAYLLOMA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#
# # CHACHAPOYAS
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CHANCHAMAYO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CHEPEN
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CHICLAYO
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#
# # CHINCHA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC ICA (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - SCOTIABANK (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#
# # CHUPACA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CONCEPCION
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # CORONEL PORTILLO
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC MAYNAS (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - SCOTIABANK (IFI)
#
# # CUSCO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - S-CRC (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # ESPINAR
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#
# # FERRENIAFE
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # GRAN CHIMU
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC TRUJILLO (IFI)
#
# # HUAMANGA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # HUANCAVELICA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # HUANCAYO
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - CRAC (Tipo IFI)
#     - CRAC RAIZ (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
#
# # HUANTA
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#
# # HUANUCO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC CUSCO (IFI)
#
# # HUARAL
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # HUAROCHIRI
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # HUAURA
# - FCTP (Producto)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - SCOTIABANK (IFI)
#
# # HUAYLAS
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#
# # HUAYTARA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#
# # ICA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
#   - CRAC (Tipo IFI)
#     - CRAC RAIZ (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#
# # ICA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#
# # LIMA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC SULLANA (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#     - CMAC TRUJILLO (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - S-CRC (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
# # ILO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # ISLAY
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#
# # JAEN
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # JAUJA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # LA CONVENCION
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # LA MAR
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # LAMAS
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC MAYNAS (IFI)
#
# # LAMBAYEQUE
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - EDPYME (Tipo IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - BANBIF (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - BANBIF (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#
# # LEONCIO PRADO
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # MARISCAL CACERES
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#
# # MARISCAL NIETO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - SCOTIABANK (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # MAYNAS
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # MELGAR
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # MORROPON
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#
# # MOYOBAMBA
# - FCTP (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#
# # NAZCA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # OXAPAMPA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # PACASMAYO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CREDITO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#
# # PADRE ABAD
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # PAITA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#
# # PASCO
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#
# # PAUCARTAMBO
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # PICOTA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
#   - EDPYME (Tipo IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#
# # PISCO
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC ICA (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC SULLANA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # PIURA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC SULLANA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - CREDISCOTIA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#
# # PUNO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#
# # QUISPICANCHI
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # RIOJA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC MAYNAS (IFI)
#
# # RODRIGUEZ DE MENDOZA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # SAN IGNACIO
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # SAN MARTIN
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC MAYNAS (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC MAYNAS (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC MAYNAS (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#
# # SAN ROMAN
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # SANCHEZ CARRION
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#
# # SANTA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - MI BANCO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC TRUJILLO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC TRUJILLO (IFI)
#
# # SATIPO
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # SECHURA
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # SULLANA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - CONTINENTAL (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC TRUJILLO (IFI)
#     - CMAC HUANCAYO (IFI)
#   - CRAC (Tipo IFI)
#     - CRAC RAIZ (IFI)
#   - EDPYME (Tipo IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#     - EDPYME MICASITA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
#
# # TACNA
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TACNA (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#
# # TALARA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - CREDITO (IFI)
#     - BANCO PICHINCHA (IFI)
# - S-CRC (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # TAMBOPATA
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC CUSCO (IFI)
#
# # TARMA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#
# # TOCACHE
# - NCMV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # TRUJILLO
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC SULLANA (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - BANCO PICHINCHA (IFI)
#     - COMERCIO (IFI)
#     - CONTINENTAL (IFI)
#     - CREDITO (IFI)
#     - INTERBANK (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#     - CMAC CUSCO (IFI)
#     - CMAC HUANCAYO (IFI)
#     - CMAC TRUJILLO (IFI)
#   - EDPYME (Tipo IFI)
#     - EDPYME MICASITA (IFI)
#     - EMPRESA DE CREDITO VIVELA S.A. (IFI)
#
# # TUMBES
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - INTERBANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - BANBIF (IFI)
#     - CONTINENTAL (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
#
# # UTCUBAMBA
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#     - CONTINENTAL (IFI)
#     - SCOTIABANK (IFI)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
# - NMIV (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#     - SCOTIABANK (IFI)
#
# # VIRU
# - FCTP (Producto)
#   - BANCO (Tipo IFI)
#     - CONTINENTAL (IFI)
#   - CAC (Tipo IFI)
#     - CAC PACIFICO (IFI)
#   - FINANCIERA (Tipo IFI)
#     - FINANCIERA EFECTIVA S. A (IFI)
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - BANCO PICHINCHA (IFI)
#     - CONTINENTAL (IFI)
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC AREQUIPA (IFI)
#
# # YAULI
# - NCMV (Producto)
#   - BANCO (Tipo IFI)
#     - CREDITO (IFI)
#
# # ZARUMILLA
# - NMIV (Producto)
#   - CMAC (Tipo IFI)
#     - CMAC HUANCAYO (IFI)
